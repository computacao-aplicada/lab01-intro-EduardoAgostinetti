# %% [markdown]
# <a href="https://colab.research.google.com/github/computacao-aplicada/lab01-intro-EduardoAgostinetti/blob/main/C%C3%B3pia_de_Aula01_Introducao_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 01: Introdução à Visão Computacional e Computação Gráfica
#
# ### 🎯 Objetivos da Aula
# - Compreender o que é Visão Computacional.
# - Diferenciar Visão Computacional, Processamento de Imagens e Computação Gráfica.
# - Realizar manipulações simples com imagens.
# - Explorar conceitos de pixels, resoluções e canais de cor.

# %% [markdown]
# ## O que é Visão Computacional?
#
# A **Visão Computacional** é uma área da Inteligência Artificial que busca permitir que os computadores 'vejam' e interpretem o mundo visual, assim como os humanos.
#
# Ela utiliza imagens e vídeos como entrada e tenta extrair informações úteis, como:
# - Detecção de objetos
# - Reconhecimento facial
# - Segmentação de imagem
# - Rastreamento de movimento
#
# A **Computação Gráfica**, por outro lado, está mais voltada à geração de imagens — como renderizar cenas em 3D.
#
# Já o **Processamento de Imagens** se concentra na transformação e análise de imagens (normalmente 2D) para melhorar a qualidade ou extrair características.
#
# | Área                  | Foco                             |
# |-----------------------|----------------------------------|
# | Visão Computacional   | Entendimento e interpretação     |
# | Computação Gráfica    | Geração de imagens               |
# | Processamento de Imagens | Manipulação e melhoria de imagens |

# %%
# Importação das bibliotecas necessárias
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Exibir gráficos inline
# %matplotlib inline

# %% [markdown]
# ## Exemplo prático: Carregar e visualizar uma imagem

# %%
# Carregar imagem de exemplo
from PIL import Image
import requests

url = "https://images.unsplash.com/photo-1745810187217-4d9e1ccfd9d5?ixlib=rb-4.1.0&q=85&fm=jpg&crop=entropy&cs=srgb&w=640"
image = Image.open(requests.get(url, stream=True).raw)
image = image.convert("RGB")  # Garante 3 canais

# Mostrar imagem
plt.imshow(image)
plt.title("Imagem Original")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Manipulação dos canais RGB

# %%
# Separar os canais
r, g, b = image.split()

# Exibir os canais
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
for ax, channel, color in zip(axs, [r, g, b], ['R', 'G', 'B']):
    ax.imshow(channel, cmap='gray')
    ax.set_title(f'Canal {color}')
    ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conversão para escala de cinza

# %%
# Converter para escala de cinza
gray_image = image.convert("L")

# Mostrar imagem em tons de cinza
plt.imshow(gray_image, cmap='gray')
plt.title("Imagem em Escala de Cinza")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Explorando os pixels

# %%
# Converter para numpy e mostrar valor de alguns pixels
np_image = np.array(image)
print("Formato da imagem:", np_image.shape)
print("Valor do pixel (0, 0):", np_image[0, 0])
# Out:
# Formato da imagem: (400, 640, 3)
# Valor do pixel (0, 0): [114 109 115]

# %% [markdown]
# 1 - Exibir apenas o canal vermelho da imagem

# %%
# Exibir apenas o canal vermelho
red_channel = np.zeros_like(np_image)
red_channel[..., 0] = np_image[..., 0]  # Copia o canal vermelho

plt.imshow(red_channel)
plt.title("Apenas Canal Vermelho")
plt.axis('off')
plt.show()

# %% [markdown]
# 2 - Modificar aleatoriamente o canal vermelho e gerar a imagem novamente

# %%
# Modificar aleatoriamente o canal vermelho
random_red = np_image.copy()
random_red[..., 0] = np.random.randint(0, 256, size=random_red[..., 0].shape)

plt.imshow(random_red)
plt.title("Canal Vermelho Aleatório")
plt.axis('off')
plt.show()

# %% [markdown]
# 3 - Criar uma imagem negativa (inverter as cores)

# %%
# Criar imagem negativa
negative_image = 255 - np_image

plt.imshow(negative_image)
plt.title("Imagem Negativa")
plt.axis('off')
plt.show()

# %% [markdown]
# 4 - Salvar uma nova imagem modificada no disco

# %%
# Salvar imagem negativa no disco
negative_pil = Image.fromarray(negative_image)
negative_pil.save("imagem_negativa.png")

print("Imagem negativa salva como 'imagem_negativa.png'")
# Out:
# Imagem negativa salva como 'imagem_negativa.png'

# %% [markdown]
#  5 - Recorte um pedaço da imagem e salve em disco

# %%
# Recortar pedaço da imagem (por exemplo, metade superior)
height, width = np_image.shape[:2]
cropped = np_image[0:height//2, 0:width//2]

plt.imshow(cropped)
plt.title("Recorte da Imagem")
plt.axis('off')
plt.show()

# Salvar recorte no disco
cropped_pil = Image.fromarray(cropped)
cropped_pil.save("imagem_recortada.png")

print("Recorte salvo como 'imagem_recortada.png'")
# Out:
# Recorte salvo como 'imagem_recortada.png'

# %% [markdown]
# ## 🧠 Exercício
#
# Tente modificar o código acima para:
#
# - Exibir apenas o canal vermelho da imagem.
# - Modifique aleatoriamente o canal vermelho e gere a imagem novamente.
# - Criar uma imagem negativa (inverter as cores).
# - Salvar uma nova imagem modificada no disco.
# - Recorte um pedaço da imagem e salve em disco.
#
# ---
# Cada um dos pontos do exercício deve ser uma célula separada!
